# %%
 print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# # My first markdown heading
# ## My second markdown heading

# %% [markdown]
# This is some **bold** text

# %% [markdown]
# 1. First item
# 2. Second item
# 3. Third item

# %%
my_var = 5

# %%
result =
